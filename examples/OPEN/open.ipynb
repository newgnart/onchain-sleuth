# %%
import json, warnings, os
from pathlib import Path

warnings.filterwarnings('ignore')

if Path.cwd().name == "notebooks":
    rootdir = Path.cwd().parent
else:
    rootdir = Path.cwd()
rootdir
# Out:
# PosixPath('/home/gnart/dev/dae/evm-sleuth/examples/OPEN')

# %%
import pandas as pd
import plotly.express as px
from plotly import graph_objects as go

from evm_sleuth.utils.postgres import PostgresClient
from evm_sleuth.config import settings

client = PostgresClient(settings.postgres)

import plotly.offline as pyo

pyo.init_notebook_mode(connected=True)

# %% [markdown]
# ## Primary market

# %%
query = """
SELECT 
    chainid,
    address,
    datetime,
    topic0,
    topic1,
    topic2,
    topic3,
    data
FROM staging.decoded_logs 
WHERE address = '0x323c03c48660fe31186fa82c289b0766d331ce21'
ORDER BY datetime DESC
"""
df = pd.read_sql(query, client.sqlalchemy_engine)
df
# Out:
#       chainid                                     address  \
# 0           1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 1           1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 2           1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 3           1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 4           1  0x323c03c48660fe31186fa82c289b0766d331ce21
# ...       ...                                         ...
# 3039        1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 3040        1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 3041        1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 3042        1  0x323c03c48660fe31186fa82c289b0766d331ce21
# 3043        1  0x323c03c48660fe31186fa82c289b0766d331ce21
#
#                       datetime  \
# 0    2025-08-25 21:17:35+00:00
# 1    2025-08-25 21:17:35+00:00
# 2    2025-08-25 21:17:23+00:00
# 3    2025-08-25 21:17:23+00:00
# 4    2025-08-25 18:38:23+00:00
# ...                        ...
# 3039 2025-04-14 19:36:35+00:00
# ...

# %%
df.topic0.value_counts()
# Out:
# topic0
# 0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef    2621
# 0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925     192
# 0x168a65529db3a11aa555b702a0e4594e364bfeebed05918eeb405d36e744fa51      54
# 0x59b7c8b22741836fc393dc21baa2e8157e039b28c3ee59310f38b2847a2dd29c      47
# 0x6110599fef1b0aac49ca735ecbf5651784cdf9e35aa5fe703d48dc3d3b64e851      28
# 0xb87e607f6030a23ed9b7dac1a717610f3a3b07325269f18808ba763bdcefe7ae      27
# 0x141fb8cd64933789f8f0c349fb279430bdf2b17e78bf8147bb3a0b0269c0609a      25
# 0x7e8e2491200fd9e2cf2541c7229d5bf89f4da14659c18fc31054176c339e310b      14
# 0x4748ea993957a820f165b4e9026aecb155d4b5bd4d3e986821c56353a6160475      10
# 0x2f8788117e7eff1d82e926ec794901d17c78024a50270940304540a733656f0d       7
# 0xf6391f5c32d9c69d2a47ea670b442974b53935d1edc7fd64eb21e047a839171b       3
# 0x5806f7ef7f8d6bafce97caf329ff62db253b61c867a1b2c4da9e79dbc4ec2f22       2
# ...
